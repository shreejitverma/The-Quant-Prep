# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="TPQ.io" width="45%" align="right" border="0"><br>

# %% [markdown]
# # Analyzing Bitcoin Data from Quandl.com

# %%
import warnings; warnings.simplefilter('ignore')

# %%
import json
import urllib
import pandas as pd
import matplotlib as mpl; mpl.use('agg')
import seaborn as sns; sns.set()
# %matplotlib inline

# %%
def read_quandl(url):
    d = json.loads(urllib.urlopen(url).read())
    df = pd.DataFrame(d['data'], columns=d['column_names']
                     ).set_index('Date').sort_index()
    return df

# %% [markdown]
# ## Number of Bitcoins

# %%
url = "https://www.quandl.com/api/v1/datasets/BCHAIN/TOTBC.json"

# %%
number = read_quandl(url)

# %%
number.tail()
# Out:
#                  Value
# Date
# 2016-08-01  15790500.0
# 2016-08-02  15792425.0
# 2016-08-03  15794500.0
# 2016-08-04  15796412.5
# 2016-08-05  15798525.0

# %% [markdown]
# Number of **Bitcoins in existence**.

# %%
number.plot(figsize=(10, 5));

# %% [markdown]
# ## Bitcoin Rate

# %%
url = "https://www.quandl.com/api/v1/datasets/BAVERAGE/USD.json"

# %%
quotes = read_quandl(url)

# %%
quotes.tail()
# Out:
#             24h Average     Ask     Bid    Last  Total Volume
# Date
# 2016-08-02       598.49  496.74  493.58  496.71      81701.65
# 2016-08-03       549.97  567.96  567.16  567.77      98704.68
# 2016-08-04       575.64  581.69  580.54  581.04      43070.19
# 2016-08-05       577.11  579.20  578.71  579.20      29097.42
# 2016-08-06       579.45  590.96  590.45  590.54      41320.17

# %% [markdown]
# **Historical** Bitcoin rate in USD.

# %%
quotes[['24h Average', 'Total Volume']].plot(
        subplots=True, figsize=(10, 6));

# %% [markdown]
# Bitcoin rate to the USD **in 2016**.

# %%
quotes[['24h Average', 'Total Volume']][quotes.index > '2015-12-31'].plot(
        subplots=True, figsize=(10, 6));

# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="45%" align="right" border="0"><br>
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a> | <a href="mailto:team@tpq.io">team@tpq.io</a>
#
# **Quant Platform** |
# <a href="http://quant-platform.com">http://quant-platform.com</a>
#
# **University Certificate Program** |
# <a href="http://training.tpq.io">http://training.tpq.io</a>
#
# **Python for Finance** |
# <a href="http://python-for-finance.com" target="_blank">Python for Finance @ O'Reilly</a>
#
# **Derivatives Analytics with Python** |
# <a href="http://derivatives-analytics-with-python.com" target="_blank">Derivatives Analytics @ Wiley Finance</a>
#
# **Listed Volatility and Variance Derivatives** |
# <a href="http://lvvd.tpq.io" target="_blank">Listed VV Derivatives @ Wiley Finance</a>
